# %%
from arcgis.gis import GIS
gis = GIS("home")

# %%
gis.users.me
# Out:
# <User username:alvaro.gutierrez.preventas>

# %%
from arcgis.geometry import Point

# %%
punto = Point({
    "x":-3.69,
    "y":40.40,
    "spatialReference":{'wkid': 4326}
})

# %%
from arcgis.geocoding import reverse_geocode

# %%
resultado_reverse_geocoding = reverse_geocode(punto)
resultado_reverse_geocoding
# Out:
# {'address': {'Match_addr': 'Archivo Historico Regional',
#   'LongLabel': 'Archivo Historico Regional, Calle de Ramírez de Prado 3, 28045, Delicias, Madrid, Comunidad de Madrid, ESP',
#   'ShortLabel': 'Archivo Historico Regional',
#   'Addr_type': 'POI',
#   'Type': 'Library',
#   'PlaceName': 'Archivo Historico Regional',
#   'AddNum': '3',
#   'Address': 'Calle de Ramírez de Prado 3',
#   'Block': '',
#   'Sector': '',
#   'Neighborhood': 'Delicias',
#   'District': '',
#   'City': 'Madrid',
#   'MetroArea': '',
#   'Subregion': 'Madrid',
#   'Region': 'Comunidad de Madrid',
#   'RegionAbbr': 'MD',
#   'Territory': '',
#   'Postal': '28045',
#   'PostalExt': '',
#   'CntryName': 'España',
#   'CountryCode': 'ESP',
#   'X': -3.689575800282,
#   'Y': 40.399950916937,
#   'InputX': -3.69,
#   'InputY': 40.4,
#   'StrucType': '',
#   'StrucDet': ''},
#  'location': {'x': -3.689575800282,
#   'y': 40.399950916937,
#   'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
